# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/.shortcut-targets-by-id/1rRUZuKu_DvqrEfrad09qFlSUyUsVZj-C/DL
# Out:
# /content/drive/.shortcut-targets-by-id/1rRUZuKu_DvqrEfrad09qFlSUyUsVZj-C/DL

# %%
import pandas as pd                                     # Data analysis and manipultion tool
import numpy as np                                      # Fundamental package for linear algebra and multidimensional arrays
import tensorflow as tf                                 # Deep Learning Tool
import os                                               # OS module in Python provides a way of using operating system dependent functionality
import cv2                                              # Library for image processing
from sklearn.model_selection import train_test_split    # For splitting the data into train and validation set

# %%
labels = pd.read_csv("weather/Training_set.csv")   # loading the labels
labels.head()           # will display the first five rows in labels dataframe
# Out:
#       filename    label
# 0  Image_1.jpg  sunrise
# 1  Image_2.jpg    shine
# 2  Image_3.jpg   cloudy
# 3  Image_4.jpg    shine
# 4  Image_5.jpg  sunrise

# %%
labels.tail()            # will display the last five rows in labels dataframe
# Out:
#             filename    label
# 1043  Image_1044.jpg    foggy
# 1044  Image_1045.jpg  sunrise
# 1045  Image_1046.jpg   cloudy
# 1046  Image_1047.jpg    rainy
# 1047  Image_1048.jpg  sunrise

# %%
file_paths = [[fname, 'weather/train/' + fname] for fname in labels['filename']]

# %%
# Confirm if number of images is same as number of labels given
if len(labels) == len(file_paths):
    print('Number of labels i.e. ', len(labels), 'matches the number of filenames i.e. ', len(file_paths))
else:
    print('Number of labels does not match the number of filenames')
# Out:
# Number of labels i.e.  1048 matches the number of filenames i.e.  1048

# %%
images = pd.DataFrame(file_paths, columns=['filename', 'filepaths'])
images.head()
# Out:
#       filename                  filepaths
# 0  Image_1.jpg  weather/train/Image_1.jpg
# 1  Image_2.jpg  weather/train/Image_2.jpg
# 2  Image_3.jpg  weather/train/Image_3.jpg
# 3  Image_4.jpg  weather/train/Image_4.jpg
# 4  Image_5.jpg  weather/train/Image_5.jpg

# %%
train_data = pd.merge(images, labels, how = 'inner', on = 'filename')
train_data.head()
# Out:
#       filename                  filepaths    label
# 0  Image_1.jpg  weather/train/Image_1.jpg  sunrise
# 1  Image_2.jpg  weather/train/Image_2.jpg    shine
# 2  Image_3.jpg  weather/train/Image_3.jpg   cloudy
# 3  Image_4.jpg  weather/train/Image_4.jpg    shine
# 4  Image_5.jpg  weather/train/Image_5.jpg  sunrise

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train_data['label'] = le.fit_transform(train_data['label'])

# %%
data = []     # initialize an empty numpy array
image_size = 100      # image size taken is 100 here. one can take other size too
for i in range(len(train_data)):
  
  img_array = cv2.imread(train_data['filepaths'][i], cv2.IMREAD_GRAYSCALE)   # converting the image to gray scale

  new_img_array = cv2.resize(img_array, (image_size, image_size))      # resizing the image array
  data.append([new_img_array, train_data['label'][i]])

# %%
# image pixels of a image
data[5]
# Out:
# [array([[129, 130, 131, ..., 129, 128, 127],
#         [129, 130, 131, ..., 129, 128, 128],
#         [129, 130, 131, ..., 130, 130, 129],
#         ...,
#         [ 14,  14,  14, ...,  18,  18,  18],
#         [ 16,  13,  14, ...,  17,  17,  17],
#         [ 24,  11,  13, ...,  16,  17,  17]], dtype=uint8), 0]

# %%
np.random.shuffle(data)

# %%
x = []
y = []
for image in data:
  x.append(image[0])
  y.append(image[1])

# converting x & y to numpy array as they are list
x = np.array(x)
y = np.array(y)

# %%
np.unique(y, return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4]), array([210, 210, 209, 174, 245]))

# %%
x =  x.reshape(-1, 100, 100, 1)

# %%
# split the data
X_train, X_val, y_train, y_val = train_test_split(x,y,test_size=0.3, random_state = 42)

# %%
cnn = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(100, 100, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    tf.keras.layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2)),
    
    # tf.keras.layers.Flatten(input_shape=(100, 100, 1)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(5, activation='softmax')
])

# %%
cnn.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
cnn.fit(X_train, y_train, epochs=200, batch_size=1)
# Out:
# Epoch 1/200
# 733/733 [==============================] - 14s 3ms/step - loss: 5.0718 - accuracy: 0.3042
# Epoch 2/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.5413 - accuracy: 0.3929
# Epoch 3/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.4211 - accuracy: 0.4420
# Epoch 4/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.3038 - accuracy: 0.4925
# Epoch 5/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.6195 - accuracy: 0.4638
# Epoch 6/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.2705 - accuracy: 0.4584
# Epoch 7/200
# 733/733 [==============================] - 3s 4ms/step - loss: 1.1957 - accuracy: 0.5198
# Epoch 8/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.2227 - accuracy: 0.5007
# Epoch 9/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.1144 - accuracy: 0.5471
# Epoch 10/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.3723 - accuracy: 0.5812
# Epoch 11/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.1769 - accuracy: 0.5402
# Epoch 12/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.9329 - accuracy: 0.6262
# Epoch 13/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.8582 - accuracy: 0.6508
# Epoch 14/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.0878 - accuracy: 0.6371
# Epoch 15/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.0826 - accuracy: 0.6085
# Epoch 16/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.7596 - accuracy: 0.6917
# Epoch 17/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.6599 - accuracy: 0.7244
# Epoch 18/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.6210 - accuracy: 0.7572
# Epoch 19/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.5454 - accuracy: 0.7776
# Epoch 20/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.6153 - accuracy: 0.7722
# Epoch 21/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.0760 - accuracy: 0.7490
# Epoch 22/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.9459 - accuracy: 0.7640
# Epoch 23/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.7361 - accuracy: 0.8308
# Epoch 24/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0
200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.1184 - accuracy: 0.9686
# Epoch 139/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0757 - accuracy: 0.9782
# Epoch 140/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.3311 - accuracy: 0.9618
# Epoch 141/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.1657 - accuracy: 0.9768
# Epoch 142/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0367 - accuracy: 0.9877
# Epoch 143/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.1072 - accuracy: 0.9741
# Epoch 144/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.2089 - accuracy: 0.9741
# Epoch 145/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.3785 - accuracy: 0.9686
# Epoch 146/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0573 - accuracy: 0.9782
# Epoch 147/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0681 - accuracy: 0.9864
# Epoch 148/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.1376 - accuracy: 0.9714
# Epoch 149/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.5916 - accuracy: 0.9632
# Epoch 150/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.1962 - accuracy: 0.9754
# Epoch 151/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0494 - accuracy: 0.9823
# Epoch 152/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0136 - accuracy: 0.9945
# Epoch 153/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0134 - accuracy: 0.9945
# Epoch 154/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0180 - accuracy: 0.9932
# Epoch 155/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0193 - accuracy: 0.9918
# Epoch 156/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0120 - accuracy: 0.9932
# Epoch 157/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.8691 - accuracy: 0.9454
# Epoch 158/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0809 - accuracy: 0.9741
# Epoch 159/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0758 - accuracy: 0.9795
# Epoch 160/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0381 - accuracy: 0.9836
# Epoch 161/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.5926 - accuracy: 0.9618
# Epoch 162/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.3618 - accuracy: 0.9686
# Epoch 163/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0660 - accuracy: 0.9768
# Epoch 164/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0215 - accuracy: 0.9905
# Epoch 165/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.2644 - accuracy: 0.9686
# Epoch 166/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.8676 - accuracy: 0.9618
# Epoch 167/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0799 - accuracy: 0.9782
# Epoch 168/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.2801 - accuracy: 0.9536
# Epoch 169/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0864 - accuracy: 0.9741
# Epoch 170/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.1202 - accuracy: 0.9795
# Epoch 171/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0681 - accuracy: 0.9877
# Epoch 172/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0198 - accuracy: 0.9932
# Epoch 173/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0334 - accuracy: 0.9905
# Epoch 174/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.3292 - accuracy: 0.9659
# Epoch 175/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0376 - accuracy: 0.9823
# Epoch 176/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.5285 - accuracy: 0.9795
# Epoch 177/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0231 - accuracy: 0.9932
# Epoch 178/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0164 - accuracy: 0.9945
# Epoch 179/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0100 - accuracy: 0.9959
# Epoch 180/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0073 - accuracy: 0.9959
# Epoch 181/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0276 - accuracy: 0.9891
# Epoch 182/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.3543 - accuracy: 0.9836
# Epoch 183/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0136 - accuracy: 0.9945
# Epoch 184/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0077 - accuracy: 0.9973
# Epoch 185/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0136 - accuracy: 0.9945
# Epoch 186/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.7488 - accuracy: 0.9768
# Epoch 187/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.3319 - accuracy: 0.9509
# Epoch 188/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.3108 - accuracy: 0.9727
# Epoch 189/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0343 - accuracy: 0.9891
# Epoch 190/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0691 - accuracy: 0.9768
# Epoch 191/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0360 - accuracy: 0.9891
# Epoch 192/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0334 - accuracy: 0.9850
# Epoch 193/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.2128 - accuracy: 0.9782
# Epoch 194/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.4015 - accuracy: 0.9468
# Epoch 195/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.1175 - accuracy: 0.9782
# Epoch 196/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0307 - accuracy: 0.9877
# Epoch 197/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0631 - accuracy: 0.9809
# Epoch 198/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.0732 - accuracy: 0.9768
# Epoch 199/200
# 733/733 [==============================] - 2s 3ms/step - loss: 0.7313 - accuracy: 0.9686
# Epoch 200/200
# 733/733 [==============================] - 2s 3ms/step - loss: 1.0847 - accuracy: 0.9563

# %%
cnn.evaluate(X_val, y_val)
# Out:
# 10/10 [==============================] - 1s 14ms/step - loss: 116.1197 - accuracy: 0.3460
# [116.1197280883789, 0.3460317552089691]

# %%
# Loading the order of the image's name that has been provided
test_image_order = pd.read_csv("weather/Testing_set.csv")
test_image_order.head()
# Out:
#       filename
# 0  Image_1.jpg
# 1  Image_2.jpg
# 2  Image_3.jpg
# 3  Image_4.jpg
# 4  Image_5.jpg

# %%
file_paths = [[fname, 'weather/test/' + fname] for fname in test_image_order['filename']]

# %%
# Confirm if number of images is same as number of labels given
if len(test_image_order) == len(file_paths):
    print('Number of image names i.e. ', len(test_image_order), 'matches the number of file paths i.e. ', len(file_paths))
else:
    print('Number of image names does not match the number of filepaths')
# Out:
# Number of image names i.e.  450 matches the number of file paths i.e.  450

# %%
test_images = pd.DataFrame(file_paths, columns=['filename', 'filepaths'])
test_images.head()
# Out:
#       filename                 filepaths
# 0  Image_1.jpg  weather/test/Image_1.jpg
# 1  Image_2.jpg  weather/test/Image_2.jpg
# 2  Image_3.jpg  weather/test/Image_3.jpg
# 3  Image_4.jpg  weather/test/Image_4.jpg
# 4  Image_5.jpg  weather/test/Image_5.jpg

# %%
test_pixel_data = []     # initialize an empty numpy array
image_size = 100      # image size taken is 100 here. one can take other size too
for i in range(len(test_images)):
  
  img_array = cv2.imread(test_images['filepaths'][i], cv2.IMREAD_GRAYSCALE)   # converting the image to gray scale

  new_img_array = cv2.resize(img_array, (image_size, image_size))      # resizing the image array

  test_pixel_data.append(new_img_array)

# %%
test_pixel_data = np.array(test_pixel_data)

# %%
test_pixel_data =  test_pixel_data.reshape(-1, 100, 100, 1)

# %%
pred = cnn.predict(test_pixel_data)

# %%
# The predicted values are the probabilities value
pred[0]
# Out:
# array([0., 0., 1., 0., 0.], dtype=float32)

# %%
prediction = []
for value in pred:
  prediction.append(np.argmax(value))

# %%
predictions = le.inverse_transform(prediction)

# %%
res = pd.DataFrame({'filename': test_images['filename'], 'label': predictions})  # prediction is nothing but the final predictions of your model on input features of your new unseen test data
res.to_csv("submission.csv", index = False)      # the csv file will be saved locally on the same location where this notebook is located.

# %%
res = pd.DataFrame({'filename': test_images['filename'], 'label': predictions})  # prediction is nothing but the final predictions of your model on input features of your new unseen test data
res.to_csv("submission.csv", index = False) 

# To download the csv file locally
from google.colab import files        
files.download('submission.csv')
